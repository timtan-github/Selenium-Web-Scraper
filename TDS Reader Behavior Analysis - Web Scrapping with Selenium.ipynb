# %%
import time
import sys
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
webdriver_path = r'C:\Users\chromedriver.exe'

# %%
# Selenium

def get_profile_urls(pub_url):
    
    ''' 
        :Params:
         pub_url - URL link of a medium publication i.e. https://medium.com/search/users?q=towards%20data%20science

        :Description:
         Scrapes links related to user profiles from a publication page. i.e. https://medium.com/@kozyrkov
         
        :Returns:
         Returns a list of user names and user profile urls
         
    '''

    # Store search results
    user_names = []
    user_urls = []

    # Path to webdriver
    browser = webdriver.Chrome(webdriver_path)

    # URL to scrape
    browser.get(pub_url)
    time.sleep(1)

    # Get body
    elem = browser.find_element_by_tag_name("body")

    # No. of times to scroll
    no_of_pagedowns = 100

    while no_of_pagedowns:
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.5)
        no_of_pagedowns-=1

    # Get tag
    a_tag = browser.find_elements_by_class_name("link.link--primary.u-accentColor--hoverTextNormal")

    for a in a_tag:
        user_names.append(a.text)
        user_urls.append(a.get_attribute("href"))

    browser.quit()

    print(f'No. of usernames: {len(user_names)}')
    print(user_names[-5:])
    print(f'No. of urls: {len(user_urls)}')
    print(user_urls[-5:])
    
    return user_names, user_urls

# %%
# Selenium

def get_writer_profile(browser,writer_profile_df,writer_profiles_col):
    
    ''' 
        :Params:
         browser - Selenium's browser session
         writer_profile_df - A pandas dataframe where new post entries are appended to
         writer_profiles_col - List of columns names in "writer_profile_df"

        :Description:
         "get_writer_profile" extracts information from each post, creates a new entry for "writer_profile_df" and appends it.
         Any posts that fails to be extracted is ignored and an error counter is kept.
         
        :Returns:
         Returns "writer_profile_df" with new appended entries and an error count
         
    '''
    
    # Initialize List
    user_name, user_profile_desc, user_followers, top_writer_flag = [],[],[],[]
        
    # Get user_name 
    match_tag = browser.find_element_by_tag_name("h1")
    user_name.append(match_tag.text)

    # Get user_profile_desc
    match_tag = browser.find_element_by_tag_name("p")
    user_profile_desc.append(match_tag.text)

    # Get user_followers
    try:
        match_tag = browser.find_element_by_partial_link_text("Followers")
        if match_tag.text.split()[0][-1]=="K":
            user_followers.append(float(match_tag.text.split()[0][:-1]) * 1000)
        else:
            user_followers.append(float(match_tag.text.split()[0]))
    except:
        user_followers.append(float(0))
        pass

    # Get top_writer_flag
    try:
        match_tag = browser.find_elements_by_tag_name("span")
        count=1
        for match in match_tag:
            if "Top writer" in match.text:
                top_writer_flag.append(float(1))
                break
            else:
                if count==5:
                    top_writer_flag.append(float(0))
                    break
                count+=1
    except:
        pass
    
    writer_profile ={
                     'user_name': user_name,
                     'user_profile_desc': user_profile_desc,
                     'user_followers': user_followers,
                     'top_writer_flag':top_writer_flag
                    }
    
    df_mismatch = 0
    try:
        # Create new entry
        create_new_entry = pd.DataFrame(writer_profile, columns = writer_profiles_col)

        # Appends new entry to posts_df
        writer_profile_df = writer_profile_df.append(create_new_entry, ignore_index=True)
    except:
        df_mismatch+=1
        pass
    
    return writer_profile_df, df_mismatch

# %%
# Beautifulsoup

def get_posts(browser,posts_df,post_details_col):
        
    ''' 
        :Params:
         browser - Selenium's browser session
         posts_df - A pandas dataframe where new post entries are appended to
         post_details_col - List of columns names in "posts_df"

        :Description:
         "get_posts" extracts information from each post, creates a new entry for "posts_df" and appends it.
         Any posts that fails to be extracted is ignored and an error counter is kept.
         
        :Returns:
         Returns "posts_df" with new appended entries and an error count
         
    '''
    
    # Switch to beautifulsoup for bulk of extraction
    page_content = BeautifulSoup(browser.page_source,"html.parser")

    # Loops through each post
    df_mismatch = 0
    ends_with_yc = re.compile(r'(..\s){5}y c')
    for row in page_content.find_all('div', class_=ends_with_yc):

        # Reset list
        user_name, title, publisher, claps, date_posted, read_time= [],[],[],[],[],[]

        # Search for title
        try:
            title_tag = row.find_all('h1')[0]
            title.append(title_tag.text)
        except:
            title.append("")
            pass

        # Search for user_name and publisher_name
        try:
            pub_tag = row.find_all('span')[0].find('div')
            publisher.append(' '.join(pub_tag.text.split()[pub_tag.text.split().index("in")+1:]))
            user_name.append(' '.join(pub_tag.text.split()[:pub_tag.text.split().index("in")]))
        except:
            publisher.append(pub_tag)
            user_name.append(pub_tag)
            pass

        # Search for claps
        try:
            claps_tag = row.find_all('h4')[0].text
            if claps_tag[-1]=="K":
                claps.append(float(claps_tag[:-1]) * 1000)
            else:
                claps.append(float(claps_tag))
        except:
            # Post with no claps do not have H4 tag
            claps.append(float(0))
            pass

        # Search for date_posted and read_time
        try:
            dp_rt_tag = row.find_all('span')[3].find('div')
            dp_tag = dp_rt_tag.text.split('·')[0]
            rt_tag = float(dp_rt_tag.text.split('·')[1].split()[0])
            date_posted.append(dp_tag.strip())
            read_time.append(rt_tag)
        except:
            pass

        # Post details
        post_details = {
                        'user_name': user_name,
                        'title': title,
                        'publisher': publisher,
                        'claps': claps,
                        'date_posted': date_posted,
                        'read_time':read_time
                        }

        try:
            # Create new entry
            create_new_entry = pd.DataFrame(post_details, columns = post_details_col)

            # Appends new entry to posts_df
            posts_df = posts_df.append(create_new_entry, ignore_index=True)
        except:
            df_mismatch+=1
            pass
    
    return posts_df, df_mismatch

# %%
# Selenium

def extract_information(url,posts_df,writer_profile_df,post_details_col,writer_profiles_col):
    
    ''' 
        :Params:
         url - A user's profile link i.e. https://medium.com/@kozyrkov
         posts_df - A pandas dataframe where new post entries are appended to
         writer_profile_df - A pandas dataframe where new profile entries are appended to
         post_details_col - List of column names in "posts_df"
         writer_profiles_col - List of column names in "writer_profile_df"

        :Description:
         Initilizes a Selenium browser for each URL recieved to being extraction process
         
        :Returns:
         Returns "posts_df" and "writer_profile_df" with new appended entries and a consolidated error count
         
    '''
    
    # Path to webdriver
    browser = webdriver.Chrome(webdriver_path)
    
    # URL to scrape
    browser.get(url)
    time.sleep(1)

    # Get body
    elem = browser.find_element_by_tag_name("body")

    # No. of times to scroll
    no_of_pagedowns = 100

    while no_of_pagedowns:
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(0.2)
        no_of_pagedowns-=1
        
    # Get posts
    posts_df, error_count_post = get_posts(browser,posts_df,post_details_col)

    # Get profiles
    writer_profile_df, error_count_profiles = get_writer_profile(browser,writer_profile_df,writer_profiles_col)
    
    error_count = error_count_post + error_count_profiles;
    
    browser.quit()
    
    return posts_df, writer_profile_df, error_count

# %%
# url_list = ['https://medium.com/@kozyrkov','https://medium.com/@ssrosa','https://medium.com/@neha_mangal','https://medium.com/@parulnith']

# Get profile urls
_,url_list = get_profile_urls("https://medium.com/search/users?q=towards%20data%20science")

# Set column names
writer_profiles_col = ["user_name", "user_profile_desc", "user_followers", "top_writer_flag"]
post_details_col = ["user_name", "title", "publisher", "claps", "date_posted", "read_time"]

# Initalize empty dfs
writer_profile_df = pd.DataFrame(None, columns = writer_profiles_col)
posts_df = pd.DataFrame(None, columns = post_details_col)

# Loop through URL list
t0 = datetime.now()
time_counter = 0
error_count = 0
save_state = 0
for url in url_list:
    
    time_counter += 1
    sys.stdout.write("Processed: %s / %s \r" % (time_counter, len(url_list)))
    sys.stdout.flush()
    
    posts_df, writer_profile_df, error_retrieved = extract_information(url,posts_df,writer_profile_df,post_details_col,writer_profiles_col)
    
    error_count += error_retrieved
    
    # save to csv every 50 urls
    if save_state%50==1:
        # Write to CSVs
        writer_profile_df.to_csv(r'C:\Users\tds_scrape\writer_profile_df.csv')
        posts_df.to_csv(r'C:\Users\tds_scrape\posts_df.csv')
    
    save_state+=1
    
    print("Processed: %s / %s -- Elapse Time: %s" % (time_counter,len(url_list),datetime.now()-t0))
    print(f"Errors due to input mismatch: {error_count}")
    
# Write to CSVs
writer_profile_df.to_csv(r'C:\Users\writer_profile_df.csv')
posts_df.to_csv(r'C:\Users\posts_df.csv')
# Out:
# No. of usernames: 319
# ['Hanh Duyen (Katie Meo)', 'Jeferson Machado Santos', 'Srimal Ashish', 'Walter Wiggins', 'Kristoffer Hebert']
# No. of urls: 319
# ['https://medium.com/@hanhduyen', 'https://medium.com/@jefersonmsantos', 'https://medium.com/@srimalashish', 'https://medium.com/@walterfwiggins', 'https://medium.com/@khbrt']
# Processed: 1 / 319 -- Elapse Time: 0:01:05.018769
# Errors due to input mismatch: 0
# Processed: 2 / 319 -- Elapse Time: 0:02:09.160244
# Errors due to input mismatch: 0
# Processed: 3 / 319 -- Elapse Time: 0:03:07.962388
# Errors due to input mismatch: 2
# Processed: 4 / 319 -- Elapse Time: 0:04:17.537913
# Errors due to input mismatch: 4
# Processed: 5 / 319 -- Elapse Time: 0:05:21.948715
# Errors due to input mismatch: 4
# Processed: 6 / 319 -- Elapse Time: 0:06:26.515560
# Errors due to input mismatch: 4
# Processed: 7 / 319 -- Elapse Time: 0:07:28.559767
# Errors due to input mismatch: 6
# Processed: 8 / 319 -- Elapse Time: 0:08:03.062549
# Errors due to input mismatch: 8
# Processed: 9 / 319 -- Elapse Time: 0:08:59.579869
# Errors due to input mismatch: 9
# Processed: 10 / 319 -- Elapse Time: 0:10:03.269019
# Errors due to input mismatch: 9
# Processed: 11 / 319 -- Elapse Time: 0:11:07.191041
# Errors due to input mismatch: 9
# Processed: 12 / 319 -- Elapse Time: 0:12:05.914461
# Errors due to input mismatch: 10
# Processed: 13 / 319 -- Elapse Time: 0:13:03.910818
# Errors due to input mismatch: 12
# Processed: 14 / 319 -- Elapse Time: 0:14:02.819527
# Errors due to input mismatch: 13
# Processed: 15 / 319 -- Elapse Time: 0:15:02.736230
# Errors due to input mismatch: 14
# Processed: 16 / 319 -- Elapse Time: 0:16:01.263418
# Errors due to input mismatch: 15
# Processed: 17 / 319 -- Elapse Time: 0:17:01.167876
# Errors due to input mismatch: 17
# Processed: 18 / 319 -- Elapse Time: 0:17:59.969572
# Errors due to input mismatch: 19
# Processed: 19 / 319 -- Elapse Time: 0:18:57.804620
# Errors due to input mismatch: 20
# Processed: 20 / 319 -- Elapse Time: 0:19:53.826219
# Errors due to input mismatch: 22
# Processed: 21 / 319 -- Elapse Time: 0:20:49.096800
# Errors due to input mismatch: 24
# Processed: 22 / 319 -- Elapse Time: 0:21:28.278791
# Errors due to input mismatch: 26
# Processed: 23 / 319 -- Elapse Time: 0:22:23.906645
# Errors due to input mismatch: 28
# Processed: 24 / 319 -- Elapse Time: 0:23:22.994105
# Errors due to input mismatch: 30
# Processed: 25 / 319 -- Elapse Time: 0:24:26.273302
# Errors due to input mismatch: 32
# Processed: 26 / 319 -- Elapse Time: 0:25:21.855684
# Errors due to input mismatch: 33
# Processed: 27 / 319 -- Elapse Time: 0:26:18.601297
# Errors due to input mismatch: 34
# Processed: 28 / 319 -- Elapse Time: 0:27:43.343940
# Errors due to input mismatch: 34
# Processed: 29 / 319 -- Elapse Time: 0:28:40.269255
# Errors due to input mismatch: 35
# Processed: 30 / 319 -- Elapse Time: 0:29:38.621251
# Errors due to input mismatch: 36
# Processed: 31 / 319 -- Elapse Time: 0:30:34.472453
# Errors due to input mismatch: 38
# Processed: 32 / 319 -- Elapse Time: 0:31:07.454351
# Errors due to input mismatch: 40
# Processed: 33 / 319 -- Elapse Time: 0:32:01.573676
# Errors due to input mismatch: 42
# Processed: 34 / 319 -- Elapse Time: 0:32:58.030482
# Errors due to input mismatch: 44
# Processed: 35 / 319 -- Elapse Time: 0:33:53.767072
# Errors due to input mismatch: 45
# Processed: 36 / 319 -- Elapse Time: 0:34:29.359237
# Errors due to input mismatch: 47
# Processed: 37 / 319 -- Elapse Time: 0:35:02.505907
# Errors due to input mismatch: 49
# Processed: 38 / 319 -- Elapse Time: 0:35:58.431143
# Errors due to input mismatch: 51
# Processed: 39 / 319 -- Elapse Time: 0:36:54.532832
# Errors due to input mismatch: 53
# Processed: 40 / 319 -- Elapse Time: 0:37:52.249727
# Errors due to input mismatch: 55
# Processed: 41 / 319 -- Elapse Time: 0:38:44.400754
# Errors due to input mismatch: 57
# Processed: 42 / 319 -- Elapse Time: 0:39:41.812939
# Errors due to input mismatch: 59
# Processed: 43 / 319 -- Elapse Time: 0:40:38.872237
# Errors due to input mismatch: 60
# Processed: 44 / 319 -- Elapse Time: 0:41:34.462230
# Errors due to input mismatch: 62
# Processed: 45 / 319 -- Elapse Time: 0:42:28.862372
# Errors due to input mismatch: 63
# Processed: 46 / 319 -- Elapse Time: 0:43:04.836047
# Errors due to input mismatch: 65
# Processed: 47 / 319 -- Elapse Time: 0:43:59.099409
# Errors due to input mismatch: 67
# Processed: 48 / 319 -- Elapse Time: 0:44:55.926480
# Errors due to input mismatch: 68
# Processed: 49 / 319 -- Elapse Time: 0:45:48.178005
# Errors due to input mismatch: 69
# Processed: 50 / 319 -- Elapse Time: 0:46:54.176235
# Errors due to input mismatch: 69
# Processed: 51 / 319 -- Elapse Time: 0:47:49.320096
# Errors due to input mismatch: 71
# Processed: 52 / 319 -- Elapse Time: 0:48:43.500980
# Errors due to input mismatch: 72
# Processed: 53 / 319 -- Elapse Time: 0:49:38.373476
# Errors due to input mismatch: 73
# Processed: 54 / 319 -- Elapse Time: 0:50:34.252118
# Errors due to input mismatch: 74
# Processed: 55 / 319 -- Elapse Time: 0:51:40.194112
# Errors due to input mismatch: 74
# Processed: 56 / 319 -- Elapse Time: 0:52:32.952483
# Errors due to input mismatch: 75
# Processed: 57 / 319 -- Elapse Time: 0:53:11.141607
# Errors due to input mismatch: 77
# Processed: 58 / 319 -- Elapse Time: 0:54:08.706879
# Errors due to input mismatch: 79
# Processed: 59 / 319 -- Elapse Time: 0:55:06.202639
# Errors due to input mismatch: 81
# Processed: 60 / 319 -- Elapse Time: 0:55:58.938184
# Errors due to input mismatch: 82
# Processed: 61 / 319 -- Elapse Time: 0:56:54.655551
# Errors due to input mismatch: 83
# Processed: 62 / 319 -- Elapse Time: 0:57:50.222608
# Errors due to input mismatch: 85
# Processed: 63 / 319 -- Elapse Time: 0:58:52.006761
# Errors due to input mismatch: 86
# Processed: 64 / 319 -- Elapse Time: 0:59:46.639171
# Errors due to input mismatch: 87
# Processed: 65 / 319 -- Elapse Time: 1:00:22.972374
# Errors due to input mismatch: 89
# Processed: 66 / 319 -- Elapse Time: 1:01:00.761562
# Errors due to input mismatch: 90
# Processed: 67 / 319 -- Elapse Time: 1:01:36.029408
# Errors due to input mismatch: 91
# Processed: 68 / 319 -- Elapse Time: 1:02:12.738337
# Errors due to input mismatch: 93
# Processed: 69 / 319 -- Elapse Time: 1:03:07.102105
# Errors due to input mismatch: 94
# Processed: 70 / 319 -- Elapse Time: 1:04:03.499519
# Errors due to input mismatch: 96
# Processed: 71 / 319 -- Elapse Time: 1:04:59.043497
# Errors due to input mismatch: 98
# Processed: 72 / 319 -- Elapse Time: 1:05:54.658660
# Errors due to input mismatch: 99
# Processed: 73 / 319 -- Elapse Time: 1:06:48.548030
# Errors due to input mismatch: 100
# Processed: 74 / 319 -- Elapse Time: 1:07:26.350211
# Errors due to input mismatch: 102
# Processed: 75 / 319 -- Elapse Time: 1:08:21.622725
# Errors due to input mismatch: 104
# Processed: 76 / 319 -- Elapse Time: 1:09:21.673114
# Errors due to input mismatch: 105
# Processed: 77 / 319 -- Elapse Time: 1:10:06.393203
# Errors due to input mismatch: 107
# Processed: 78 / 319 -- Elapse Time: 1:11:02.098432
# Errors due to input mismatch: 108
# Processed: 79 / 319 -- Elapse Time: 1:11:41.516658
# Errors due to input mismatch: 109
# Processed: 80 / 319 -- Elapse Time: 1:12:38.088674
# Errors due to input mismatch: 111
# Processed: 81 / 319 -- Elapse Time: 1:13:30.078609
# Errors due to input mismatch: 113
# Processed: 82 / 319 -- Elapse Time: 1:14:07.366302
# Errors due to input mismatch: 114
# Processed: 83 / 319 -- Elapse Time: 1:15:02.722800
# Errors due to input mismatch: 116
# Processed: 84 / 319 -- Elapse Time: 1:15:57.829499
# Errors due to input mismatch: 118
# Processed: 85 / 319 -- Elapse Time: 1:16:59.059186
# Errors due to input mismatch: 120
# Processed: 86 / 319 -- Elapse Time: 1:17:53.721767
# Errors due to input mismatch: 122
# Processed: 87 / 319 -- Elapse Time: 1:18:59.269958
# Errors due to input mismatch: 122
# Processed: 88 / 319 -- Elapse Time: 1:19:42.843463
# Errors due to input mismatch: 122
# Processed: 89 / 319 -- Elapse Time: 1:20:36.767500
# Errors due to input mismatch: 124
# Processed: 90 / 319 -- Elapse Time: 1:21:30.971296
# Errors due to input mismatch: 125
# Processed: 91 / 319 -- Elapse Time: 1:22:25.714547
# Errors due to input mismatch: 126
# Processed: 92 / 319 -- Elapse Time: 1:23:19.562136
# Errors due to input mismatch: 127
# Processed: 93 / 319 -- Elapse Time: 1:24:10.449610
# Errors due to input mismatch: 128
# Processed: 94 / 319 -- Elapse Time: 1:25:04.734420
# Errors due to input mismatch: 129
# Processed: 95 / 319 -- Elapse Time: 1:25:38.259483
# Errors due to input mismatch: 130
# Processed: 96 / 319 -- Elapse Time: 1:26:32.605970
# Errors due to input mismatch: 131
# Processed: 97 / 319 -- Elapse Time: 1:27:04.531226
# Errors due to input mismatch: 132
# Processed: 98 / 319 -- Elapse Time: 1:27:36.932995
# Errors due to input mismatch: 133
# Processed: 99 / 319 -- Elapse Time: 1:28:31.527956
# Errors due to input mismatch: 134
# Processed: 100 / 319 -- Elapse Time: 1:29:27.024595
# Errors due to input mismatch: 135
# Processed: 101 / 319 -- Elapse Time: 1:30:02.262436
# Errors due to input mismatch: 137
# Processed: 102 / 319 -- Elapse Time: 1:30:54.428109
# Errors due to input mismatch: 138
# Processed: 103 / 319 -- Elapse Time: 1:31:27.266435
# Errors due to input mismatch: 140
# Processed: 104 / 319 -- Elapse Time: 1:32:23.740147
# Errors due to input mismatch: 142
# Processed: 105 / 319 -- Elapse Time: 1:33:19.115473
# Errors due to input mismatch: 144
# Processed: 106 / 319 -- Elapse Time: 1:34:09.183783
# Errors due to input mismatch: 145
# Processed: 107 / 319 -- Elapse Time: 1:35:04.035158
# Errors due to input mismatch: 147
# Processed: 108 / 319 -- Elapse Time: 1:35:42.157295
# Errors due to input mismatch: 148
# Processed: 109 / 319 -- Elapse Time: 1:36:38.412882
# Errors due to input mismatch: 150
# Processed: 110 / 319 -- Elapse Time: 1:37:13.500931
# Errors due to input mismatch: 152
# Processed: 111 / 319 -- Elapse Time: 1:38:05.504695
# Errors due to input mismatch: 154
# Processed: 112 / 319 -- Elapse Time: 1:38:58.736760
# Errors due to input mismatch: 156
# Processed: 113 / 319 -- Elapse Time: 1:39:32.172626
# Errors due to input mismatch: 158
# Processed: 114 / 319 -- Elapse Time: 1:40:27.262827
# Errors due to input mismatch: 160
# Processed: 115 / 319 -- Elapse Time: 1:41:02.459013
# Errors due to input mismatch: 161
# Processed: 116 / 319 -- Elapse Time: 1:41:54.957773
# Errors due to input mismatch: 163
# Processed: 117 / 319 -- Elapse Time: 1:42:48.414300
# Errors due to input mismatch: 165
# Processed: 118 / 319 -- Elapse Time: 1:43:47.762363
# Errors due to input mismatch: 166
# Processed: 119 / 319 -- Elapse Time: 1:44:23.658642
# Errors due to input mismatch: 168
# Processed: 120 / 319 -- Elapse Time: 1:45:17.573364
# Errors due to input mismatch: 170
# Processed: 121 / 319 -- Elapse Time: 1:46:20.727378
# Errors due to input mismatch: 172
# Processed: 122 / 319 -- Elapse Time: 1:47:15.375609
# Errors due to input mismatch: 174
# Processed: 123 / 319 -- Elapse Time: 1:48:08.089074
# Errors due to input mismatch: 176
# Processed: 124 / 319 -- Elapse Time: 1:49:00.949890
# Errors due to input mismatch: 178
# Processed: 125 / 319 -- Elapse Time: 1:49:54.154700
# Errors due to input mismatch: 180
# Processed: 126 / 319 -- Elapse Time: 1:50:27.699593
# Errors due to input mismatch: 182
# Processed: 127 / 319 -- Elapse Time: 1:51:02.187946
# Errors due to input mismatch: 184
# Processed: 128 / 319 -- Elapse Time: 1:51:54.609999
# Errors due to input mismatch: 185
# Processed: 129 / 319 -- Elapse Time: 1:52:51.607676
# Errors due to input mismatch: 186
# Processed: 130 / 319 -- Elapse Time: 1:53:57.519742
# Errors due to input mismatch: 188
# Processed: 131 / 319 -- Elapse Time: 1:54:54.198117
# Errors due to input mismatch: 189
# Processed: 132 / 319 -- Elapse Time: 1:55:48.452505
# Errors due to input mismatch: 191
# Processed: 133 / 319 -- Elapse Time: 1:56:42.593326
# Errors due to input mismatch: 192
# Processed: 134 / 319 -- Elapse Time: 1:57:37.879497
# Errors due to input mismatch: 193
# Processed: 135 / 319 -- Elapse Time: 1:58:31.467659
# Errors due to input mismatch: 193
# Processed: 136 / 319 -- Elapse Time: 1:59:28.208372
# Errors due to input mismatch: 195
# Processed: 137 / 319 -- Elapse Time: 2:00:23.643872
# Errors due to input mismatch: 197
# Processed: 138 / 319 -- Elapse Time: 2:01:20.033403
# Errors due to input mismatch: 198
# Processed: 139 / 319 -- Elapse Time: 2:02:13.940454
# Errors due to input mismatch: 199
# Processed: 140 / 319 -- Elapse Time: 2:03:11.007578
# Errors due to input mismatch: 201
# Processed: 141 / 319 -- Elapse Time: 2:04:06.254946
# Errors due to input mismatch: 203
# Processed: 142 / 319 -- Elapse Time: 2:05:02.197008
# Errors due to input mismatch: 205
# Processed: 143 / 319 -- Elapse Time: 2:05:57.388592
# Errors due to input mismatch: 207
# Processed: 144 / 319 -- Elapse Time: 2:06:52.187858
# Errors due to input mismatch: 209
# Processed: 145 / 319 -- Elapse Time: 2:07:47.096885
# Errors due to input mismatch: 210
# Processed: 146 / 319 -- Elapse Time: 2:08:45.956754
# Errors due to input mismatch: 212
# Processed: 147 / 319 -- Elapse Time: 2:09:40.011548
# Errors due to input mismatch: 213
# Processed: 148 / 319 -- Elapse Time: 2:10:35.081527
# Errors due to input mismatch: 214
# Processed: 149 / 319 -- Elapse Time: 2:11:31.598044
# Errors due to input mismatch: 216
# Processed: 150 / 319 -- Elapse Time: 2:12:27.007501
# Errors due to input mismatch: 218
# Processed: 151 / 319 -- Elapse Time: 2:13:22.259339
# Errors due to input mismatch: 220
# Processed: 152 / 319 -- Elapse Time: 2:14:19.443630
# Errors due to input mismatch: 222
# Processed: 153 / 319 -- Elapse Time: 2:15:14.666880
# Errors due to input mismatch: 224
# Processed: 154 / 319 -- Elapse Time: 2:16:15.718298
# Errors due to input mismatch: 225
# Processed: 155 / 319 -- Elapse Time: 2:16:49.604560
# Errors due to input mismatch: 226
# Processed: 156 / 319 -- Elapse Time: 2:17:45.805098
# Errors due to input mismatch: 228
# Processed: 157 / 319 -- Elapse Time: 2:18:41.317975
# Errors due to input mismatch: 229
# Processed: 158 / 319 -- Elapse Time: 2:19:34.148099
# Errors due to input mismatch: 230
# Processed: 159 / 319 -- Elapse Time: 2:20:06.212678
# Errors due to input mismatch: 232
# Processed: 160 / 319 -- Elapse Time: 2:21:01.523003
# Errors due to input mismatch: 234
# Processed: 161 / 319 -- Elapse Time: 2:21:58.777563
# Errors due to input mismatch: 235
# Processed: 162 / 319 -- Elapse Time: 2:22:54.933326
# Errors due to input mismatch: 236
# Processed: 163 / 319 -- Elapse Time: 2:23:48.455153
# Errors due to input mismatch: 238
# Processed: 164 / 319 -- Elapse Time: 2:24:43.265669
# Errors due to input mismatch: 240
# Processed: 165 / 319 -- Elapse Time: 2:25:36.252564
# Errors due to input mismatch: 241
# Processed: 166 / 319 -- Elapse Time: 2:26:33.257813
# Errors due to input mismatch: 243
# Processed: 167 / 319 -- Elapse Time: 2:27:25.345887
# Errors due to input mismatch: 244
# Processed: 168 / 319 -- Elapse Time: 2:28:17.292752
# Errors due to input mismatch: 246
# Processed: 169 / 319 -- Elapse Time: 2:29:14.551570
# Errors due to input mismatch: 247
# Processed: 170 / 319 -- Elapse Time: 2:30:08.940908
# Errors due to input mismatch: 249
# Processed: 171 / 319 -- Elapse Time: 2:31:01.919926
# Errors due to input mismatch: 250
# Processed: 172 / 319 -- Elapse Time: 2:31:56.805077
# Errors due to input mismatch: 251
# Processed: 173 / 319 -- Elapse Time: 2:32:31.805599
# Errors due to input mismatch: 252
# Processed: 174 / 319 -- Elapse Time: 2:33:25.904812
# Errors due to input mismatch: 253
# Processed: 175 / 319 -- Elapse Time: 2:34:35.897248
# Errors due to input mismatch: 253
# Processed: 176 / 319 -- Elapse Time: 2:35:31.880219
# Errors due to input mismatch: 254
# Processed: 177 / 319 -- Elapse Time: 2:36:27.676762
# Errors due to input mismatch: 255
# Processed: 178 / 319 -- Elapse Time: 2:37:19.842754
# Errors due to input mismatch: 257
# Processed: 179 / 319 -- Elapse Time: 2:38:13.258717
# Errors due to input mismatch: 258
# Processed: 180 / 319 -- Elapse Time: 2:38:52.306485
# Errors due to input mismatch: 260
# Processed: 181 / 319 -- Elapse Time: 2:39:26.132640
# Errors due to input mismatch: 262
# Processed: 182 / 319 -- Elapse Time: 2:40:20.741154
# Errors due to input mismatch: 264
# Processed: 183 / 319 -- Elapse Time: 2:41:13.505225
# Errors due to input mismatch: 266
# Processed: 184 / 319 -- Elapse Time: 2:42:06.830090
# Errors due to input mismatch: 267
# Processed: 185 / 319 -- Elapse Time: 2:43:07.584296
# Errors due to input mismatch: 267
# Processed: 186 / 319 -- Elapse Time: 2:44:00.462850
# Errors due to input mismatch: 268
# Processed: 187 / 319 -- Elapse Time: 2:44:55.139631
# Errors due to input mismatch: 269
# Processed: 188 / 319 -- Elapse Time: 2:45:50.055553
# Errors due to input mismatch: 271
# Processed: 189 / 319 -- Elapse Time: 2:46:44.407541
# Errors due to input mismatch: 272
# Processed: 190 / 319 -- Elapse Time: 2:47:37.151793
# Errors due to input mismatch: 273
# Processed: 191 / 319 -- Elapse Time: 2:48:29.624833
# Errors due to input mismatch: 274
# Processed: 192 / 319 -- Elapse Time: 2:49:24.541068
# Errors due to input mismatch: 275
# Processed: 193 / 319 -- Elapse Time: 2:50:21.267294
# Errors due to input mismatch: 275
# Processed: 194 / 319 -- Elapse Time: 2:51:13.457708
# Errors due to input mismatch: 277
# Processed: 195 / 319 -- Elapse Time: 2:52:06.383687
# Errors due to input mismatch: 278
# Processed: 196 / 319 -- Elapse Time: 2:53:01.428892
# Errors due to input mismatch: 279
# Processed: 197 / 319 -- Elapse Time: 2:53:56.891644
# Errors due to input mismatch: 281
# Processed: 198 / 319 -- Elapse Time: 2:54:48.300434
# Errors due to input mismatch: 282
# Processed: 199 / 319 -- Elapse Time: 2:55:43.437994
# Errors due to input mismatch: 284
# Processed: 200 / 319 -- Elapse Time: 2:56:40.620937
# Errors due to input mismatch: 284
# Processed: 201 / 319 -- Elapse Time: 2:57:35.157076
# Errors due to input mismatch: 285
# Processed: 202 / 319 -- Elapse Time: 2:58:27.828613
# Errors due to input mismatch: 285
# Processed: 203 / 319 -- Elapse Time: 2:59:32.416561
# Errors due to input mismatch: 287
# Processed: 204 / 319 -- Elapse Time: 3:00:27.707339
# Errors due to input mismatch: 289
# Processed: 205 / 319 -- Elapse Time: 3:01:21.532247
# Errors due to input mismatch: 291
# Processed: 206 / 319 -- Elapse Time: 3:02:13.061694
# Errors due to input mismatch: 293
# Processed: 207 / 319 -- Elapse Time: 3:03:09.742335
# Errors due to input mismatch: 295
# Processed: 208 / 319 -- Elapse Time: 3:04:06.043927
# Errors due to input mismatch: 297
# Processed: 209 / 319 -- Elapse Time: 3:05:02.779541
# Errors due to input mismatch: 299
# Processed: 210 / 319 -- Elapse Time: 3:05:55.194658
# Errors due to input mismatch: 301
# Processed: 211 / 319 -- Elapse Time: 3:06:49.349230
# Errors due to input mismatch: 302
# Processed: 212 / 319 -- Elapse Time: 3:07:50.004608
# Errors due to input mismatch: 304
# Processed: 213 / 319 -- Elapse Time: 3:08:42.276034
# Errors due to input mismatch: 306
# Processed: 214 / 319 -- Elapse Time: 3:09:35.694601
# Errors due to input mismatch: 308
# Processed: 215 / 319 -- Elapse Time: 3:10:30.779894
# Errors due to input mismatch: 310
# Processed: 216 / 319 -- Elapse Time: 3:11:25.123850
# Errors due to input mismatch: 312
# Processed: 217 / 319 -- Elapse Time: 3:12:17.905207
# Errors due to input mismatch: 314
# Processed: 218 / 319 -- Elapse Time: 3:13:10.676765
# Errors due to input mismatch: 315
# Processed: 219 / 319 -- Elapse Time: 3:14:05.404194
# Errors due to input mismatch: 317
# Processed: 220 / 319 -- Elapse Time: 3:14:59.858562
# Errors due to input mismatch: 320
# Processed: 221 / 319 -- Elapse Time: 3:15:33.875325
# Errors due to input mismatch: 322
# Processed: 222 / 319 -- Elapse Time: 3:16:27.132815
# Errors due to input mismatch: 323
# Processed: 223 / 319 -- Elapse Time: 3:17:19.841595
# Errors due to input mismatch: 325
# Processed: 224 / 319 -- Elapse Time: 3:17:50.999392
# Errors due to input mismatch: 326
# Processed: 225 / 319 -- Elapse Time: 3:18:43.585283
# Errors due to input mismatch: 327
# Processed: 226 / 319 -- Elapse Time: 3:19:37.047476
# Errors due to input mismatch: 328
# Processed: 227 / 319 -- Elapse Time: 3:20:32.450947
# Errors due to input mismatch: 329
# Processed: 228 / 319 -- Elapse Time: 3:21:28.598806
# Errors due to input mismatch: 331
# Processed: 229 / 319 -- Elapse Time: 3:22:02.534714
# Errors due to input mismatch: 333
# Processed: 230 / 319 -- Elapse Time: 3:22:53.168540
# Errors due to input mismatch: 334
# Processed: 231 / 319 -- Elapse Time: 3:23:24.111262
# Errors due to input mismatch: 335
# Processed: 232 / 319 -- Elapse Time: 3:24:18.781621
# Errors due to input mismatch: 336
# Processed: 233 / 319 -- Elapse Time: 3:25:13.090232
# Errors due to input mismatch: 337
# Processed: 234 / 319 -- Elapse Time: 3:25:48.863778
# Errors due to input mismatch: 338
# Processed: 235 / 319 -- Elapse Time: 3:26:19.489521
# Errors due to input mismatch: 339
# Processed: 236 / 319 -- Elapse Time: 3:27:15.357765
# Errors due to input mismatch: 341
# Processed: 237 / 319 -- Elapse Time: 3:28:09.735787
# Errors due to input mismatch: 342
# Processed: 238 / 319 -- Elapse Time: 3:29:04.377861
# Errors due to input mismatch: 343
# Processed: 239 / 319 -- Elapse Time: 3:29:55.652915
# Errors due to input mismatch: 345
# Processed: 240 / 319 -- Elapse Time: 3:30:51.395336
# Errors due to input mismatch: 346
# Processed: 241 / 319 -- Elapse Time: 3:31:45.840222
# Errors due to input mismatch: 346
# Processed: 242 / 319 -- Elapse Time: 3:32:23.242409
# Errors due to input mismatch: 347
# Processed: 243 / 319 -- Elapse Time: 3:33:13.903248
# Errors due to input mismatch: 348
# Processed: 244 / 319 -- Elapse Time: 3:34:04.874744
# Errors due to input mismatch: 350
# Processed: 245 / 319 -- Elapse Time: 3:34:59.638784
# Errors due to input mismatch: 352
# Processed: 246 / 319 -- Elapse Time: 3:35:50.973967
# Errors due to input mismatch: 353
# Processed: 247 / 319 -- Elapse Time: 3:36:43.025303
# Errors due to input mismatch: 355
# Processed: 248 / 319 -- Elapse Time: 3:37:32.536144
# Errors due to input mismatch: 356
# Processed: 249 / 319 -- Elapse Time: 3:38:27.306416
# Errors due to input mismatch: 357
# Processed: 250 / 319 -- Elapse Time: 3:39:06.855616
# Errors due to input mismatch: 357
# Processed: 251 / 319 -- Elapse Time: 3:39:59.899587
# Errors due to input mismatch: 357
# Processed: 252 / 319 -- Elapse Time: 3:40:51.108695
# Errors due to input mismatch: 357
# Processed: 253 / 319 -- Elapse Time: 3:41:46.742377
# Errors due to input mismatch: 358
# Processed: 254 / 319 -- Elapse Time: 3:42:40.601360
# Errors due to input mismatch: 360
# Processed: 255 / 319 -- Elapse Time: 3:43:42.628239
# Errors due to input mismatch: 360
# Processed: 256 / 319 -- Elapse Time: 3:44:35.013518
# Errors due to input mismatch: 361
# Processed: 257 / 319 -- Elapse Time: 3:45:08.666568
# Errors due to input mismatch: 362
# Processed: 258 / 319 -- Elapse Time: 3:46:02.656708
# Errors due to input mismatch: 363
# Processed: 259 / 319 -- Elapse Time: 3:46:55.858320
# Errors due to input mismatch: 364
# Processed: 260 / 319 -- Elapse Time: 3:47:46.951701
# Errors due to input mismatch: 364
# Processed: 261 / 319 -- Elapse Time: 3:48:41.566526
# Errors due to input mismatch: 366
# Processed: 262 / 319 -- Elapse Time: 3:49:35.691707
# Errors due to input mismatch: 367
# Processed: 263 / 319 -- Elapse Time: 3:50:09.741087
# Errors due to input mismatch: 368
# Processed: 264 / 319 -- Elapse Time: 3:51:00.255206
# Errors due to input mismatch: 369
# Processed: 265 / 319 -- Elapse Time: 3:51:32.016322
# Errors due to input mismatch: 370
# Processed: 266 / 319 -- Elapse Time: 3:52:23.028063
# Errors due to input mismatch: 372
# Processed: 267 / 319 -- Elapse Time: 3:53:15.205414
# Errors due to input mismatch: 373
# Processed: 268 / 319 -- Elapse Time: 3:54:07.027806
# Errors due to input mismatch: 374
# Processed: 269 / 319 -- Elapse Time: 3:55:01.322096
# Errors due to input mismatch: 375
# Processed: 270 / 319 -- Elapse Time: 3:55:56.173686
# Errors due to input mismatch: 376
# Processed: 271 / 319 -- Elapse Time: 3:56:55.976863
# Errors due to input mismatch: 377
# Processed: 272 / 319 -- Elapse Time: 3:57:48.501990
# Errors due to input mismatch: 378
# Processed: 273 / 319 -- Elapse Time: 3:58:43.194939
# Errors due to input mismatch: 379
# Processed: 274 / 319 -- Elapse Time: 3:59:39.085647
# Errors due to input mismatch: 381
# Processed: 275 / 319 -- Elapse Time: 4:00:33.974571
# Errors due to input mismatch: 382
# Processed: 276 / 319 -- Elapse Time: 4:01:26.218210
# Errors due to input mismatch: 384
# Processed: 277 / 319 -- Elapse Time: 4:02:21.017284
# Errors due to input mismatch: 385
# Processed: 278 / 319 -- Elapse Time: 4:02:56.245873
# Errors due to input mismatch: 387
# Processed: 279 / 319 -- Elapse Time: 4:03:51.224777
# Errors due to input mismatch: 388
# Processed: 280 / 319 -- Elapse Time: 4:04:43.277269
# Errors due to input mismatch: 388
# Processed: 281 / 319 -- Elapse Time: 4:05:35.423091
# Errors due to input mismatch: 389
# Processed: 282 / 319 -- Elapse Time: 4:06:31.493975
# Errors due to input mismatch: 390
# Processed: 283 / 319 -- Elapse Time: 4:07:29.222391
# Errors due to input mismatch: 391
# Processed: 284 / 319 -- Elapse Time: 4:08:08.941578
# Errors due to input mismatch: 392
# Processed: 285 / 319 -- Elapse Time: 4:09:00.966132
# Errors due to input mismatch: 393
# Processed: 286 / 319 -- Elapse Time: 4:09:52.900906
# Errors due to input mismatch: 394
# Processed: 287 / 319 -- Elapse Time: 4:10:45.776108
# Errors due to input mismatch: 395
# Processed: 288 / 319 -- Elapse Time: 4:11:36.896672
# Errors due to input mismatch: 396
# Processed: 289 / 319 -- Elapse Time: 4:12:28.043997
# Errors due to input mismatch: 397
# Processed: 290 / 319 -- Elapse Time: 4:13:03.971755
# Errors due to input mismatch: 398
# Processed: 291 / 319 -- Elapse Time: 4:13:57.976771
# Errors due to input mismatch: 398
# Processed: 292 / 319 -- Elapse Time: 4:14:53.447452
# Errors due to input mismatch: 400
# Processed: 293 / 319 -- Elapse Time: 4:15:46.017188
# Errors due to input mismatch: 402
# Processed: 294 / 319 -- Elapse Time: 4:16:42.312380
# Errors due to input mismatch: 404
# Processed: 295 / 319 -- Elapse Time: 4:17:38.342091
# Errors due to input mismatch: 406
# Processed: 296 / 319 -- Elapse Time: 4:18:34.419457
# Errors due to input mismatch: 406
# Processed: 297 / 319 -- Elapse Time: 4:19:08.669580
# Errors due to input mismatch: 407
# Processed: 298 / 319 -- Elapse Time: 4:20:03.320846
# Errors due to input mismatch: 408
# Processed: 299 / 319 -- Elapse Time: 4:20:58.087635
# Errors due to input mismatch: 410
# Processed: 300 / 319 -- Elapse Time: 4:21:32.301267
# Errors due to input mismatch: 412
# Processed: 301 / 319 -- Elapse Time: 4:22:05.346298
# Errors due to input mismatch: 413
# Processed: 302 / 319 -- Elapse Time: 4:22:56.748211
# Errors due to input mismatch: 414
# Processed: 303 / 319 -- Elapse Time: 4:23:50.812747
# Errors due to input mismatch: 415
# Processed: 304 / 319 -- Elapse Time: 4:24:45.295534
# Errors due to input mismatch: 416
# Processed: 305 / 319 -- Elapse Time: 4:25:38.832735
# Errors due to input mismatch: 417
# Processed: 306 / 319 -- Elapse Time: 4:26:09.732895
# Errors due to input mismatch: 418
# Processed: 307 / 319 -- Elapse Time: 4:27:00.551950
# Errors due to input mismatch: 419
# Processed: 308 / 319 -- Elapse Time: 4:27:31.417060
# Errors due to input mismatch: 420
# Processed: 309 / 319 -- Elapse Time: 4:28:23.510082
# Errors due to input mismatch: 421
# Processed: 310 / 319 -- Elapse Time: 4:29:15.848466
# Errors due to input mismatch: 422
# Processed: 311 / 319 -- Elapse Time: 4:30:11.019045
# Errors due to input mismatch: 424
# Processed: 312 / 319 -- Elapse Time: 4:31:06.197914
# Errors due to input mismatch: 424
# Processed: 313 / 319 -- Elapse Time: 4:32:00.338227
# Errors due to input mismatch: 425
# Processed: 314 / 319 -- Elapse Time: 4:32:57.196687
# Errors due to input mismatch: 427
# Processed: 315 / 319 -- Elapse Time: 4:33:52.193732
# Errors due to input mismatch: 429
# Processed: 316 / 319 -- Elapse Time: 4:34:45.540306
# Errors due to input mismatch: 429
# Processed: 317 / 319 -- Elapse Time: 4:35:22.945510
# Errors due to input mismatch: 431
# Processed: 318 / 319 -- Elapse Time: 4:36:16.009370
# Errors due to input mismatch: 433
# Processed: 319 / 319 -- Elapse Time: 4:37:14.072705
# Errors due to input mismatch: 435

# %%
writer_profile_df
# Out:
#                    user_name  \
# 0              Will Koehrsen
# 1            Cassie Kozyrkov
# 2                  Jeff Hale
# 3               Parul Pandey
# 4                   TDS Team
# ..                       ...
# 286   Hanh Duyen (Katie Meo)
# 287  Jeferson Machado Santos
# 288            Srimal Ashish
# 289           Walter Wiggins
# 290        Kristoffer Hebert
#
#                                      user_profile_desc  user_followers  \
# 0    Data Scientist at Cortex Intel, Data Science C...         30000.0
# 1    Head of Decision Intelligence, Google. ❤️ Stat...         29000.0
# 2    I write about data science. Join my Data Aweso...         13100.0
# 3            Data Science+Community+Evangelism @H2O.ai         12700.0
# 4    Sharing concepts, ideas, and codes. Learn more...         11000.0
# ..                                                 ...             ...
# 286  Toward Data Science for Social Goods. Founder ...             3.0
# 287  Currently making a career shift toward data sc...             1.0
# 288  Toward the world of Data Science. Machine Lear...            42.0
# 289  BWH/Harvard radiology resident, MGH-BWH Center...           116.0
# 290  I am working toward a simpler, more meaningful...            24.0
#
#      top_writer_flag
# 0                0.0
# 1                1.0
# 2                1.0
# 3                0.0
# 4                0.0
# ..               ...
# 286              0.0
# 287              0.0
# 288              0.0
# 289              0.0
# 290              0.0
#
# [291 rows x 4 columns]

# %%
posts_df
# Out:
#                     user_name  \
# 0               Will Koehrsen
# 1               Will Koehrsen
# 2         [[[Will Koehrsen]]]
# 3         [[[Will Koehrsen]]]
# 4         [[[Will Koehrsen]]]
# ...                       ...
# 5519  [[[Kristoffer Hebert]]]
# 5520  [[[Kristoffer Hebert]]]
# 5521  [[[Kristoffer Hebert]]]
# 5522  [[[Kristoffer Hebert]]]
# 5523  [[[Kristoffer Hebert]]]
#
#                                                   title  \
# 0     The Poisson Distribution and Poisson Process E...
# 1                           A Data Science Conversation
# 2                 12 Lessons from 55,000 pages of books
# 3                                         Books of 2019
# 4              “Just Do It” Won’t Get You to Your Goals
# ...                                                 ...
# 5519                            Intro to React — Part 1
# 5520                       What’s new in ES6 Javascript
# 5521                             Jasmine BDD with Karma
# 5522                                 Intro to AngularJS
# 5523                                 Intro to AngularJS
#
#                     publisher   claps   date_posted  read_time
# 0        Towards Data Science  6800.0  Jan 21, 2019       14.0
# 1        Towards Data Science   172.0        Mar 10        3.0
# 2         [[[Will Koehrsen]]]  1100.0         Jan 3       14.0
# 3         [[[Will Koehrsen]]]   413.0         Jan 1       58.0
# 4         [[[Will Koehrsen]]]   338.0  Dec 27, 2019       12.0
# ...                       ...     ...           ...        ...
# 5519  [[[Kristoffer Hebert]]]     0.0  Aug 30, 2015        2.0
# 5520  [[[Kristoffer Hebert]]]     2.0  Aug 17, 2015        2.0
# 5521  [[[Kristoffer Hebert]]]     3.0  Jul 19, 2015        3.0
# 5522  [[[Kristoffer Hebert]]]     0.0  Jun 28, 2015        2.0
# 5523  [[[Kristoffer Hebert]]]     1.0  May 25, 2015        2.0
#
# [5524 rows x 6 columns]
